# %%
from matplotlib import pyplot as plt
import numpy as np
# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()
# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
#importing the .py file
import b_python_script
# import b_python_script as b
# Out:
# ['/Users/rabinatwayana/Rabina/CDE II/software_development/PLUS_softwaredev_2025_rabina', '/Users/rabinatwayana/Rabina/anaconda3/lib/python312.zip', '/Users/rabinatwayana/Rabina/anaconda3/lib/python3.12', '/Users/rabinatwayana/Rabina/anaconda3/lib/python3.12/lib-dynload', '', '/Users/rabinatwayana/Rabina/anaconda3/lib/python3.12/site-packages', '/Users/rabinatwayana/Rabina/anaconda3/lib/python3.12/site-packages/aeosa']
#
# Please wait a moment while I gather a list of all available modules...
# /Users/rabinatwayana/Rabina/anaconda3/lib/python3.12/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 13.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /Users/rabinatwayana/Rabina/anaconda3/lib/python3.12/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# /Users/rabinatwayana/Rabina/anaconda3/lib/python3.12/pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# /Users/rabinatwayana/Rabina/anaconda3/lib/python3.12/site-packages/pydantic/experimental/__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
#
# No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# 7f0197f6d050da244d93__mypyc boltons             jupyter_lsp         repo_cli
# AppKit              botocore            jupyter_server      reprlib
# Cocoa               bottleneck          jupyter_server_terminals requests
# CoreFoundation      brotli              jupyterlab          requests_file
# CoreServices        bs4                 jupyterlab_plotly   requests_toolbelt
# FSEvents            builtins            jupyterlab_pygments resource
# Foundation          bz2                 jupyterlab_server   rfc3339_validator
# IPython             cProfile            jupyterlab_widgets  rfc3986_validator
# OpenSSL             cached_property     jwt                 rich
# PIL                 cachetools          keyring             rlcompleter
# PyQt5               calendar            keyword             rope
# __future__          certifi             kiwisolver          rpds
# __hello__           cffi                lazy_loader         rtree
# __phello__          cgi                 lazy_object_proxy   ruamel_yaml
# _abc                cgitb               lckr_jupyterlab_variableinspector runpy
# _aix_support        chardet             lib2to3             s3fs
# _argon2_cffi_bindings charset_normalizer  libarchive          sched
# _ast                chunk               libmambapy          scipy
# _asyncio            cli                 lief                scrapy
# _bisect             click               linecache           seaborn
# _black_version      cloudpickle         linkify_it          secrets
# _blake2             cmath               llvmlite            select
# _brotli             cmd                 lmdb                selectors
# _bz2                code                locale              semver
# _cffi_backend       codecs              locket              send2trash
# _codecs             codeop              logging             service_identity
# _codecs_cn          collections         lxml                setuptools
# _codecs_hk          colorama            lz4                 shelve
# _codecs_iso2022     colorcet            lzma                shlex
# _codecs_jp          colorsys            mactypes            shutil
# _codecs_kr          comm                mailbox             signal
# _codecs_tw          compileall          mailcap             sipbuild
# _collections        concurrent          mamba               site
# _collections_abc    conda               markdown            six
# _compat_pickle      conda_build         markdown_it         skimage
# _compression        conda_content_trust markupsafe          sklearn
# _contextvars        conda_env           marshal             slugify
# _crypt              conda_index         math                smart_open
# _csv                conda_libmamba_solver matplotlib          smmap
# _ctypes             conda_pack          matplotlib_inline   smtplib
# _ctypes_test        conda_package_handling mccabe              snappy
# _curses             conda_package_streaming mdit_py_plugins     sndhdr
# _curses_panel       conda_token         mdurl               sniffio
# _datetime           configparser        menuinst            snowballstemmer
# _dbm                constantly          mimetypes           socket
# _decimal            contextlib          mistune             socketserver
# _distutils_hack     contextvars         mmap                socks
# _elementtree        contourpy           modulefinder        sockshandler
# _functools          cookiecutter        more_itertools      sortedcontainers
# _hashlib            copy                mpmath              soupsieve
# _heapq              copyreg             msgpack             sphinx
# _imp                cpuinfo             multidict           spyder
# _io                 crypt               multipledispatch    spyder_kernels
# _json               cryptography        multiprocessing     sqlalchemy
# _locale             cssselect           mypy                sqlite3
# _lsprof             csv                 mypy_extensions     sre_compile
# _lzma               ctypes              mypyc               sre_constants
# _markupbase         curl                navigator_updater   sre_parse
# _md5                curses              nbclient            ssl
# _multibytecodec     cv2                 nbconvert           stack_data
# _multiprocessing    cycler              nbformat            stat
# _opcode             cytoolz             nest_asyncio        statistics
# _operator           dask                netrc               statsmodels
# _osx_support        dask_expr           networkx            streamlit
# _pickle             dataclasses         nis                 string
# _plotly_future_     datashader          nltk                stringprep
# _plotly_utils       datetime            nntplib             stringzilla
# _posixshmem         dateutil            notebook            struct
# _posixsubprocess    dbm                 notebook_shim       subprocess
# _py_abc             debugpy             ntpath              sunau
# _pydatetime         decimal             nturl2path          sympy
# _pydecimal          decorator           numba               symtable
# _pyio               defusedxml          numbergen           sys
# _pylong             diff_match_patch    numbers             sysconfig
# _pytest             difflib             numexpr             syslog
# _queue              dill                numpy               tables
# _random             dis                 numpydoc            tabnanny
# _scproxy            distributed         objc                tabulate
# _sha1               distro              opcode              tarfile
# _sha2               docstring_to_markdown openpyxl            tblib
# _sha3               doctest             operator            telnetlib
# _signal             docutils            optparse            tempfile
# _sitebuiltins       dotenv              os                  tenacity
# _socket             email               osax                terminado
# _sqlite3            encodings           overrides           termios
# _sre                ensurepip           packaging           test
# _ssl                entrypoints         pandas              test_pycosat
# _stat               enum                pandocfilters       text_unidecode
# _statistics         erfa                panel               textdistance
# _string             errno               param               textwrap
# _strptime           et_xmlfile          parsel              this
# _struct             eval_type_backport  parso               threading
# _symtable           executing           partd               threadpoolctl
# _sysconfigdata__darwin_darwin fastjsonschema      pathlib             three_merge
# _sysconfigdata_arm64_apple_darwin20_0_0 faulthandler        pathspec            tifffile
# _testbuffer         fcntl               patsy               time
# _testcapi           filecmp             pdb                 timeit
# _testclinic         fileinput           pexpect             tinycss2
# _testimportmultiple filelock            pickle              tkinter
# _testinternalcapi   flake8              pickleshare         tldextract
# _testmultiphase     flask               pickletools         tlz
# _testsinglephase    fnmatch             pip                 token
# _thread             fontTools           pipes               tokenize
# _threading_local    fractions           pkce                toml
# _tkinter            frozendict          pkg_resources       tomli
# _tokenize           frozenlist          pkginfo             tomlkit
# _tracemalloc        fsspec              pkgutil             tomllib
# _typing             ftplib              platform            toolz
# _uuid               functools           platformdirs        tornado
# _warnings           gc                  plistlib            tqdm
# _watchdog_fsevents  genericpath         plotly              trace
# _weakref            gensim              pluggy              traceback
# _weakrefset         getopt              ply                 tracemalloc
# _xxinterpchannels   getpass             poplib              traitlets
# _xxsubinterpreters  gettext             posix               truststore
# _xxtestfuzz         git                 posixpath           tty
# _yaml               gitdb               pprint              turtle
# _zoneinfo           glob                profile             turtledemo
# a_python_script     graphlib            prometheus_client   twisted
# abc                 greenlet            prompt_toolkit      types
# aem                 grp                 protego             typing
# aifc                gzip                pstats              typing_extensions
# aiobotocore         h5py                psutil              tzdata
# aiohttp             hashlib             pty                 uc_micro
# aioitertools        heapdict            ptyprocess          ujson
# aiosignal           heapq               pure_eval           unicodedata
# alabaster           hmac                pwd                 unicodedata2
# albucore            holoviews           py                  unidecode
# albumentations      html                py_compile          unittest
# altair              http                pyarrow             urllib
# anaconda_anon_usage hvplot              pyasn1              urllib3
# anaconda_catalogs   hyperlink           pyasn1_modules      uu
# anaconda_cloud_auth idlelib             pyclbr              uuid
# anaconda_navigator  idna                pycodestyle         venv
# anaconda_project    imagecodecs         pycosat             w3lib
# annotated_types     imageio             pycparser           warnings
# antigravity         imagesize           pyct                watchdog
# anyio               imaplib             pycurl              wave
# appdirs             imblearn            pydantic            wcwidth
# applaunchservices   imghdr              pydantic_core       weakref
# appnope             importlib           pydeck              webbrowser
# appscript           importlib_metadata  pydispatch          webencodings
# archspec            incremental         pydoc               websocket
# argon2              inflection          pydoc_data          werkzeug
# argparse            iniconfig           pydocstyle          whatthepatch
# array               inspect             pyexpat             wheel
# arrow               intake              pyflakes            widgetsnbextension
# ast                 intervaltree        pygments            wrapt
# astroid             io                  pylab               wsgiref
# astropy             ipaddress           pylint              wurlitzer
# astropy_iers_data   ipykernel           pylint_venv         xarray
# asttokens           ipykernel_launcher  pyls_spyder         xdrlib
# async_lru           ipython_genutils    pylsp               xlwings
# asyncio             ipywidgets          pylsp_black         xlwingsjs
# atexit              isort               pylsp_jsonrpc       xml
# atomicwrites        isympy              pyodbc              xmlrpc
# attr                itemadapter         pyparsing           xxlimited
# attrs               itemloaders         pytest              xxlimited_35
# audioop             itertools           pythonjsonlogger    xxsubtype
# automat             itsdangerous        pytoolconfig        xyzservices
# autopep8            jedi                pytz                yaml
# b_python_script     jellyfish           pyviz_comms         yapf
# babel               jinja2              pywt                yapf_third_party
# base64              jmespath            qdarkstyle          yapftests
# bcrypt              joblib              qstylizer           yarl
# bdb                 json                qtawesome           zict
# binaryornot         json5               qtconsole           zipapp
# binascii            jsonpatch           qtpy                zipfile
# binstar_client      jsonpointer         queue               zipimport
# bisect              jsonschema          queuelib            zipp
# black               jsonschema_specifications quopri              zlib
# blackd              jupyter             random              zmq
# bleach              jupyter_client      re                  zoneinfo
# blib2to3            jupyter_console     readline            zope
# blinker             jupyter_core        referencing         zstandard
# bokeh               jupyter_events      regex
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
#access the variable from imported python file
b_python_script.days_of_the_week
# Out:
# 7

# %%
# terminal command 
# !ls
# !pwd
# Out:
# Bio_Jakir.md          Sahar Biography.md    c_python_script.ipynb
# Ola_Bio.md            __pycache__           nicole_about_me
# README.md             a_python_script.py
# SW_Contribution2      b_python_script.py
# /Users/rabinatwayana/Rabina/CDE II/software_development/PLUS_softwaredev_2025_rabina
